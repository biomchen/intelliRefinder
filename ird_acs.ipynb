# %% [markdown]
# # IntelliRefinder
# #### Using machine learning to identify the mortgage refinance opportunity for mortgage lenders
#
# Meng Chen, PhD
# Data Science Fellow at Insight Data Science
# [LinkedIn](https://www.linkedin.com/in/mlchen/); [GitHub](https://github.com/biomchen)

# %% [markdown]
# #### This notebook is for preprocessing the American Community Survey data

# %%
from refinder import *
import modin.pandas as mpd
from pathlib import Path
import matplotlib.pyplot as plt

# %% [markdown]
# #### Load the csv files

# %%
king_folder = '../data/acs/wa/king'
king_path = Path(king_folder)
king_csvs = list(king_path.glob('*.{}'.format('csv')))

# %% [markdown]
# #### Inspect the coloums

# %%
def csv_inspect(folder, header=1):
    path = Path(folder)
    files = list(path.glob('*.{}'.format('csv')))
    for file in files:
        df = pd.read_csv(file, header=header)
        df = df.drop([0])
        print(df.columns)
        
csv_inspect('../data/acs/wa/king')
# Out:
# Index(['Id', 'Id2', 'Geography',
#        'Total; Estimate; Population 16 years and over',
#        'Total; Margin of Error; Population 16 years and over',
#        'Labor Force Participation Rate; Estimate; Population 16 years and over',
#        'Labor Force Participation Rate; Margin of Error; Population 16 years and over',
#        'Employment/Population Ratio; Estimate; Population 16 years and over',
#        'Employment/Population Ratio; Margin of Error; Population 16 years and over',
#        'Unemployment rate; Estimate; Population 16 years and over',
#        ...
#        'Unemployment rate; Estimate; EDUCATIONAL ATTAINMENT - Population 25 to 64 years - Some college or associate's degree',
#        'Unemployment rate; Margin of Error; EDUCATIONAL ATTAINMENT - Population 25 to 64 years - Some college or associate's degree',
#        'Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 to 64 years - Bachelor's degree or higher',
#        'Total; Margin of Error; EDUCATIONAL ATTAINMENT - Population 25 to 64 years - Bachelor's degree or higher',
#        'Labor Force Participation Rate; Estimate; EDUCATIONAL ATTAINMENT - Population 25 to 64 years - Bachelor's degree or higher',
#        'Labor Force Participation Rate; Margin of Error; EDUCATIONAL ATTAINMENT - Population 25 to 64 years - Bachelor's degree or higher',
#        'Employment/Population Ratio; Estimate; EDUCATIONAL ATTAINMENT - Population 25 to 64 years - Bachelor's degree or higher',
#        'Employment/Population Ratio; Margin of Error; EDUCATIONAL ATTAINMENT - Population 25 to 64 years - Bachelor's degree or higher',
#        'Unemployment rate; Estimate; EDUCATIONAL ATTAINMENT - Population 25 to 64 years - Bachelor's degree or higher',
#        'Unemployment rate; Margin of Error; EDUCATIONAL ATTAINMENT - Population 25 to 64 years - Bachelor's degree or higher'],
#       dtype='object', length=283)
# Index(['Id', 'Id2', 'Geography', 'Estimate; Total:', 'Margin of Error; Total:',
#        'Estimate; Total: - Less than 5 minutes',
#        'Margin of Error; Total: - Less than 5 minutes',
#        'Estimate; Total: - 5 to 9 minutes',
#        'Margin of Error; Total: - 5 to 9 minutes',
#        'Estimate; Total: - 10 to 14 minutes',
#        'Margin of Error; Total: - 10 to 14 minutes',
#        'Estimate; Total: - 15 to 19 minutes',
#        'Margin of Error; Total: - 15 to 19 minutes',
#        'Estimate; Total: - 20 to 24 minutes',
#        'Margin of Error; Total: - 20 to 24 minutes',
#        'Estimate; Total: - 25 to 29 minutes',
#        'Margin of Error; Total: - 25 to 29 minutes',
#        'Estimate; Total: - 30 to 34 minutes',
#        'Margin of Error; Total: - 30 to 34 minutes',
#        'Estimate; Total: - 35 to 39 minutes',
#        'Margin of Error; Total: - 35 to 39 minutes',
#        'Estimate; Total: - 40 to 44 minutes',
#        'Margin of Error; Total: - 40 to 44 minutes',
#        'Estimate; Total: - 45 to 59 minutes',
#        'Margin of Error; Total: - 45 to 59 minutes',
#        'Estimate; Total: - 60 to 89 minutes',
#        'Margin of Error; Total: - 60 to 89 minutes',
#        'Estimate; Total: - 90 or more minutes',
#        'Margin of Error; Total: - 90 or more minutes'],
#       dtype='object')
# Index(['Id', 'Id2', 'Geography',
#        'Total; Estimate; Population 15 years and over',
#        'Total; Margin of Error; Population 15 years and over',
#        'Now married (except separated); Estimate; Population 15 years and over',
#        'Now married (except separated); Margin of Error; Population 15 years and over',
#        'Widowed; Estimate; Population 15 years and over',
#        'Widowed; Margin of Error; Population 15 years and over',
#        'Divorced; Estimate; Population 15 years and over',
#        ...
#        'Now married (except separated); Estimate; PERCENT ALLOCATED - Marital status',
#        'Now married (except separated); Margin of Error; PERCENT ALLOCATED - Marital status',
#        'Widowed; Estimate; PERCENT ALLOCATED - Marital status',
#        'Widowed; Margin of Error; PERCENT ALLOCATED - Marital status',
#        'Divorced; Estimate; PERCENT ALLOCATED - Marital status',
#        'Divorced; Margin of Error; PERCENT ALLOCATED - Marital status',
#        'Separated; Estimate; PERCENT ALLOCATED - Marital status',
#        'Separated; Margin of Error; PERCENT ALLOCATED - Marital status',
#        'Never married; Estimate; PERCENT ALLOCATED - Marital status',
#        'Never married; Margin of Error; PERCENT ALLOCATED - Marital status'],
#       dtype='object', length=375)
# Index(['Id', 'Id2', 'Geography', 'Total; Estimate; Total population',
#        'Total; Margin of Error; Total population',
#        'Percent; Estimate; Total population',
#        'Percent; Margin of Error; Total population',
#        'Male; Estimate; Total population',
#        'Male; Margin of Error; Total population',
#        'Percent Male; Estimate; Total population',
#        ...
#        'Percent; Estimate; PERCENT ALLOCATED - Age',
#        'Percent; Margin of Error; PERCENT ALLOCATED - Age',
#        'Male; Estimate; PERCENT ALLOCATED - Age',
#        'Male; Margin of Error; PERCENT ALLOCATED - Age',
#        'Percent Male; Estimate; PERCENT ALLOCATED - Age',
#        'Percent Male; Margin of Error; PERCENT ALLOCATED - Age',
#        'Female; Estimate; PERCENT ALLOCATED - Age',
#        'Female; Margin of Error; PERCENT ALLOCATED - Age',
#        'Percent Female; Estimate; PERCENT ALLOCATED - Age',
#        'Percent Female; Margin of Error; PERCENT ALLOCATED - Age'],
#       dtype='object', length=459)
# Index(['Id', 'Id2', 'Geography', 'Estimate; Total:', 'Margin of Error; Total:',
#        'Estimate; In households:', 'Margin of Error; In households:',
#        'Estimate; In households: - Under 3 years',
#        'Margin of Error; In households: - Under 3 years',
#        'Estimate; In households: - 3 and 4 years',
#        'Margin of Error; In households: - 3 and 4 years',
#        'Estimate; In households: - 5 years',
#        'Margin of Error; In households: - 5 years',
#        'Estimate; In households: - 6 to 8 years',
#        'Margin of Error; In households: - 6 to 8 years',
#        'Estimate; In households: - 9 to 11 years',
#        'Margin of Error; In households: - 9 to 11 years',
#        'Estimate; In households: - 12 to 14 years',
#        'Margin of Error; In households: - 12 to 14 years',
#        'Estimate; In households: - 15 to 17 years',
#        'Margin of Error; In households: - 15 to 17 years',
#        'Estimate; In group quarters', 'Margin of Error; In group quarters'],
#       dtype='object')

# %%
headers = ['Labor Force Participation Rate; Estimate; Population 16 years and over',
           'Employment/Population Ratio; Estimate; Population 16 years and over',
           'Unemployment rate; Estimate; Population 16 years and over',
           'Estimate; Total: - Less than 5 minutes',
           'Estimate; Total: - 5 to 9 minutes',
           'Estimate; Total: - 10 to 14 minutes',
           'Estimate; Total: - 15 to 19 minutes',
           'Estimate; Total: - 20 to 24 minutes',
           'Estimate; Total: - 25 to 29 minutes',
           'Estimate; Total: - 30 to 34 minutes',
           'Estimate; Total: - 35 to 39 minutes',
           'Estimate; Total: - 40 to 44 minutes',
           'Estimate; Total: - 45 to 59 minutes',
           'Estimate; Total: - 60 to 89 minutes',
           'Estimate; Total: - 90 or more minutes',
           'Now married (except separated); Estimate; Population 15 years and over',
           'Widowed; Estimate; Population 15 years and over',
           'Divorced; Estimate; Population 15 years and over',
           'Separated; Estimate; Population 15 years and over',
           'Never married; Estimate; Population 15 years and over',
           'Male; Estimate; Total population',
           'Percent Male; Estimate; Total population',
           'Female; Estimate; Total population',
           'Percent Female; Estimate; Total population',
           'Estimate; In households: - Under 3 years',
           'Estimate; In households: - 3 and 4 years',
           'Estimate; In households: - 5 years',
           'Estimate; In households: - 6 to 8 years',
           'Estimate; In households: - 9 to 11 years',
           'Estimate; In households: - 12 to 14 years',
           'Estimate; In households: - 15 to 17 years']

# %%
king_csv_df = pd.DataFrame()

for csv in king_csvs:
    unwanted = 'Margin of Error'
    df_csv = pd.read_csv(csv, header=1)
    df_csv = df_csv.drop([0])
    df_csv.set_index(['Geography'], inplace=True)
    df_csv.drop(columns=['Id','Id2'], inplace=True)
    name_drops = []
    for names in df_csv.columns:
        if unwanted in names:
            name_drops.append(names)
        else:
            continue
    df_csv.drop(columns=name_drops, inplace=True)
    king_csv_df = pd.concat([king_csv_df, df_csv], axis=1)

king_csv_df.head()
# Out:
#                                             Total; Estimate; Population 16 years and over  \
# Geography
# Census Tract 2, King County, Washington                                              6917
# Census Tract 3, King County, Washington                                              2332
# Census Tract 4.01, King County, Washington                                           6057
# Census Tract 4.02, King County, Washington                                           4714
# Census Tract 5, King County, Washington                                              2543
#
#                                            Labor Force Participation Rate; Estimate; Population 16 years and over  \
# Geography
# Census Tract 2, King County, Washington                                                  67.5
# Census Tract 3, King County, Washington                                                  74.3
# Census Tract 4.01, King County, Washington                                               59.7
# Census Tract 4.02, King County, Washington                                               64.6
# Census Tract 5, King County, Washington                                                  62.0
#
#                                            Employment/Population Ratio; Estimate; Population 16 years and over  \
# Geography
# Census Tract 2, King County, Washington                                                  63.2
# Census Tract 3, King County, Washington                                                  72.5
# Census Tract 4.01, King County, Washington                                               56.5
# Census Tract 4.02, King County, Washington                                               62.2
# Census Tract 5, King County, Washington                                                  60.6
#
#                                            Unemployment rate; Estimate; Population 16 years and over  \
# Geography
# Census Tract 2, King County, Washington                                                   6.0
# Census Tract 3, King County, Washington                                                   2.5
# Census Tract 4.01, King County, Washington                                                4.9
# Census Tract 4.02, King County, Washington                                                3.8
# Census Tract 5, King County, Washington                                                   2.3
#
#                                             Total; Estimate; AGE - 16 to 19 years  \
# Geography
# Census Tract 2, King County, Washington                                       351
# Census Tract 3, King County, Washington                                        67
# Census Tract 4.01, King County, Washington                                    301
# Census Tract 4.02, King County, Washington                                     74
# Census Tract 5, King County, Washington                                       153
#
#                                            Labor Force Participation Rate; Estimate; AGE - 16 to 19 years  \
# Geography
# Census Tract 2, King County, Washington                                                  58.1
# Census Tract 3, King County, Washington                                                  40.3
# Census Tract 4.01, King County, Washington                                               15.0
# Census Tract 4.02, King County, Washington                                               27.0
# Census Tract 5, King County, Washington                                                   8.5
#
#                                            Employment/Population Ratio; Estimate; AGE - 16 to 19 years  \
# Geography
# Census Tract 2, King County, Washington                                                  51.9
# Census Tract 3, King County, Washington                                                  40.3
# Census Tract 4.01, King County, Washington                                               15.0
# Census Tract 4.02, King County, Washington                                               27.0
# Census Tract 5, King County, Washington                                                   8.5
#
#                                            Unemployment rate; Estimate; AGE - 16 to 19 years  \
# Geography
# Census Tract 2, King County, Washington                                                 10.8
# Census Tract 3, King County, Washington                                                  0.0
# Census Tract 4.01, King County, Washington                                               0.0
# Census Tract 4.02, King County, Washington                                               0.0
# Census Tract 5, King County, Washington                                                  0.0
#
#                                             Total; Estimate; AGE - 20 to 24 years  \
# Geography
# Census Tract 2, King County, Washington                                       487
# Census Tract 3, King County, Washington                                       113
# Census Tract 4.01, King County, Washington                                    672
# Census Tract 4.02, King County, Washington                                    142
# Census Tract 5, King County, Washington                                        57
#
#                                            Labor Force Participation Rate; Estimate; AGE - 20 to 24 years  \
# Geography
# Census Tract 2, King County, Washington                                                  85.0
# Census Tract 3, King County, Washington                                                 100.0
# Census Tract 4.01, King County, Washington                                               71.6
# Census Tract 4.02, King County, Washington                                               76.1
# Census Tract 5, King County, Washington                                                  68.4
#
#                                             ... Estimate; Total:  \
# Geography                                   ...
# Census Tract 2, King County, Washington     ...             1200
# Census Tract 3, King County, Washington     ...              507
# Census Tract 4.01, King County, Washington  ...              834
# Census Tract 4.02, King County, Washington  ...              619
# Census Tract 5, King County, Washington     ...              604
#
#                                            Estimate; In households:  \
# Geography
# Census Tract 2, King County, Washington                        1200
# Census Tract 3, King County, Washington                         507
# Census Tract 4.01, King County, Washington                      834
# Census Tract 4.02, King County, Washington                      619
# Census Tract 5, King County, Washington                         604
#
#                                             Estimate; In households: - Under 3 years  \
# Geography
# Census Tract 2, King County, Washington                                          202
# Census Tract 3, King County, Washington                                           97
# Census Tract 4.01, King County, Washington                                       288
# Census Tract 4.02, King County, Washington                                        80
# Census Tract 5, King County, Washington                                          128
#
#                                            Estimate; In households: - 3 and 4 years  \
# Geography
# Census Tract 2, King County, Washington                                         188
# Census Tract 3, King County, Washington                                          21
# Census Tract 4.01, King County, Washington                                      150
# Census Tract 4.02, King County, Washington                                       48
# Census Tract 5, King County, Washington                                          57
#
#                                            Estimate; In households: - 5 years  \
# Geography
# Census Tract 2, King County, Washington                                    33
# Census Tract 3, King County, Washington                                    43
# Census Tract 4.01, King County, Washington                                 34
# Census Tract 4.02, King County, Washington                                 79
# Census Tract 5, King County, Washington                                    55
#
#                                            Estimate; In households: - 6 to 8 years  \
# Geography
# Census Tract 2, King County, Washington                                        277
# Census Tract 3, King County, Washington                                        112
# Census Tract 4.01, King County, Washington                                      38
# Census Tract 4.02, King County, Washington                                     118
# Census Tract 5, King County, Washington                                         57
#
#                                             Estimate; In households: - 9 to 11 years  \
# Geography
# Census Tract 2, King County, Washington                                          204
# Census Tract 3, King County, Washington                                           55
# Census Tract 4.01, King County, Washington                                        47
# Census Tract 4.02, King County, Washington                                       165
# Census Tract 5, King County, Washington                                          106
#
#                                            Estimate; In households: - 12 to 14 years  \
# Geography
# Census Tract 2, King County, Washington                                           97
# Census Tract 3, King County, Washington                                          125
# Census Tract 4.01, King County, Washington                                         0
# Census Tract 4.02, King County, Washington                                        80
# Census Tract 5, King County, Washington                                           76
#
#                                            Estimate; In households: - 15 to 17 years  \
# Geography
# Census Tract 2, King County, Washington                                          199
# Census Tract 3, King County, Washington                                           54
# Census Tract 4.01, King County, Washington                                       277
# Census Tract 4.02, King County, Washington                                        49
# Census Tract 5, King County, Washington                                          125
#
#                                            Estimate; In group quarters
# Geography
# Census Tract 2, King County, Washington                              0
# Census Tract 3, King County, Washington                              0
# Census Tract 4.01, King County, Washington                           0
# Census Tract 4.02, King County, Washington                           0
# Census Tract 5, King County, Washington                              0
#
# [5 rows x 577 columns]

# %%
king_csv_df_new = king_csv_df[headers]
king_csv_df_new.head()
# Out:
#                                            Labor Force Participation Rate; Estimate; Population 16 years and over  \
# Geography
# Census Tract 2, King County, Washington                                                  67.5
# Census Tract 3, King County, Washington                                                  74.3
# Census Tract 4.01, King County, Washington                                               59.7
# Census Tract 4.02, King County, Washington                                               64.6
# Census Tract 5, King County, Washington                                                  62.0
#
#                                            Employment/Population Ratio; Estimate; Population 16 years and over  \
# Geography
# Census Tract 2, King County, Washington                                                  63.2
# Census Tract 3, King County, Washington                                                  72.5
# Census Tract 4.01, King County, Washington                                               56.5
# Census Tract 4.02, King County, Washington                                               62.2
# Census Tract 5, King County, Washington                                                  60.6
#
#                                            Unemployment rate; Estimate; Population 16 years and over  \
# Geography
# Census Tract 2, King County, Washington                                                   6.0
# Census Tract 3, King County, Washington                                                   2.5
# Census Tract 4.01, King County, Washington                                                4.9
# Census Tract 4.02, King County, Washington                                                3.8
# Census Tract 5, King County, Washington                                                   2.3
#
#                                             Estimate; Total: - Less than 5 minutes  \
# Geography
# Census Tract 2, King County, Washington                                          0
# Census Tract 3, King County, Washington                                         11
# Census Tract 4.01, King County, Washington                                      34
# Census Tract 4.02, King County, Washington                                       0
# Census Tract 5, King County, Washington                                          9
#
#                                             Estimate; Total: - 5 to 9 minutes  \
# Geography
# Census Tract 2, King County, Washington                                   217
# Census Tract 3, King County, Washington                                    93
# Census Tract 4.01, King County, Washington                                114
# Census Tract 4.02, King County, Washington                                157
# Census Tract 5, King County, Washington                                    47
#
#                                             Estimate; Total: - 10 to 14 minutes  \
# Geography
# Census Tract 2, King County, Washington                                     517
# Census Tract 3, King County, Washington                                      95
# Census Tract 4.01, King County, Washington                                  245
# Census Tract 4.02, King County, Washington                                  224
# Census Tract 5, King County, Washington                                      50
#
#                                             Estimate; Total: - 15 to 19 minutes  \
# Geography
# Census Tract 2, King County, Washington                                     407
# Census Tract 3, King County, Washington                                     158
# Census Tract 4.01, King County, Washington                                  280
# Census Tract 4.02, King County, Washington                                  326
# Census Tract 5, King County, Washington                                     117
#
#                                             Estimate; Total: - 20 to 24 minutes  \
# Geography
# Census Tract 2, King County, Washington                                     536
# Census Tract 3, King County, Washington                                     338
# Census Tract 4.01, King County, Washington                                  759
# Census Tract 4.02, King County, Washington                                  380
# Census Tract 5, King County, Washington                                     240
#
#                                             Estimate; Total: - 25 to 29 minutes  \
# Geography
# Census Tract 2, King County, Washington                                     386
# Census Tract 3, King County, Washington                                      83
# Census Tract 4.01, King County, Washington                                  365
# Census Tract 4.02, King County, Washington                                  173
# Census Tract 5, King County, Washington                                     132
#
#                                             Estimate; Total: - 30 to 34 minutes  \
# Geography
# Census Tract 2, King County, Washington                                     633
# Census Tract 3, King County, Washington                                     300
# Census Tract 4.01, King County, Washington                                  518
# Census Tract 4.02, King County, Washington                                  575
# Census Tract 5, King County, Washington                                     307
#
#                                             ...  \
# Geography                                   ...
# Census Tract 2, King County, Washington     ...
# Census Tract 3, King County, Washington     ...
# Census Tract 4.01, King County, Washington  ...
# Census Tract 4.02, King County, Washington  ...
# Census Tract 5, King County, Washington     ...
#
#                                             Percent Male; Estimate; Total population  \
# Geography
# Census Tract 2, King County, Washington                                          (X)
# Census Tract 3, King County, Washington                                          (X)
# Census Tract 4.01, King County, Washington                                       (X)
# Census Tract 4.02, King County, Washington                                       (X)
# Census Tract 5, King County, Washington                                          (X)
#
#                                             Female; Estimate; Total population  \
# Geography
# Census Tract 2, King County, Washington                                   4057
# Census Tract 3, King County, Washington                                   1379
# Census Tract 4.01, King County, Washington                                3663
# Census Tract 4.02, King County, Washington                                2592
# Census Tract 5, King County, Washington                                   1530
#
#                                             Percent Female; Estimate; Total population  \
# Geography
# Census Tract 2, King County, Washington                                            (X)
# Census Tract 3, King County, Washington                                            (X)
# Census Tract 4.01, King County, Washington                                         (X)
# Census Tract 4.02, King County, Washington                                         (X)
# Census Tract 5, King County, Washington                                            (X)
#
#                                             Estimate; In households: - Under 3 years  \
# Geography
# Census Tract 2, King County, Washington                                          202
# Census Tract 3, King County, Washington                                           97
# Census Tract 4.01, King County, Washington                                       288
# Census Tract 4.02, King County, Washington                                        80
# Census Tract 5, King County, Washington                                          128
#
#                                             Estimate; In households: - 3 and 4 years  \
# Geography
# Census Tract 2, King County, Washington                                          188
# Census Tract 3, King County, Washington                                           21
# Census Tract 4.01, King County, Washington                                       150
# Census Tract 4.02, King County, Washington                                        48
# Census Tract 5, King County, Washington                                           57
#
#                                            Estimate; In households: - 5 years  \
# Geography
# Census Tract 2, King County, Washington                                    33
# Census Tract 3, King County, Washington                                    43
# Census Tract 4.01, King County, Washington                                 34
# Census Tract 4.02, King County, Washington                                 79
# Census Tract 5, King County, Washington                                    55
#
#                                            Estimate; In households: - 6 to 8 years  \
# Geography
# Census Tract 2, King County, Washington                                        277
# Census Tract 3, King County, Washington                                        112
# Census Tract 4.01, King County, Washington                                      38
# Census Tract 4.02, King County, Washington                                     118
# Census Tract 5, King County, Washington                                         57
#
#                                            Estimate; In households: - 9 to 11 years  \
# Geography
# Census Tract 2, King County, Washington                                         204
# Census Tract 3, King County, Washington                                          55
# Census Tract 4.01, King County, Washington                                       47
# Census Tract 4.02, King County, Washington                                      165
# Census Tract 5, King County, Washington                                         106
#
#                                            Estimate; In households: - 12 to 14 years  \
# Geography
# Census Tract 2, King County, Washington                                           97
# Census Tract 3, King County, Washington                                          125
# Census Tract 4.01, King County, Washington                                         0
# Census Tract 4.02, King County, Washington                                        80
# Census Tract 5, King County, Washington                                           76
#
#                                            Estimate; In households: - 15 to 17 years
# Geography
# Census Tract 2, King County, Washington                                          199
# Census Tract 3, King County, Washington                                           54
# Census Tract 4.01, King County, Washington                                       277
# Census Tract 4.02, King County, Washington                                        49
# Census Tract 5, King County, Washington                                          125
#
# [5 rows x 31 columns]

# %%
king_csv_df_new.reset_index(inplace=True)
tract_names = []
for item in king_csv_df_new["Geography"]:
    tract = item.split(' ')[2].split(',')[0]
    tract = float(tract)
    tract_names.append(tract)
king_csv_df_new['Tract name'] = tract_names
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
king_csv_df_new.drop(columns=['Geography'], inplace=True)
king_csv_df_new.set_index(['Tract name'], inplace=True)
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
new_headers = ['Labor_Force_Participation_Rate',
               'Employment_Population_Ratio',
               'Unemployment_rate',
               'Work_Travel_Less_5_mins',
               'Work_Travel_5_to_9_mins',
               'Work_Travel_10_to_14_mins',
               'Work_Travel_15_to_19_mins',
               'Work_Travel_20_to_24_mins',
               'Work_Travel_25_to_29_mins',
               'Work_Travel_30_to_34_mins',
               'Work_Travel_35_to_39_mins',
               'Work_Travel_40_to_44_mins',
               'Work_Travel_45_to_59_mins',
               'Work_Travel_60_to_89_mins',
               'Work_Travel_90_or_more_mins',
               'Married',
               'Widowed',
               'Divorced',
               'Separated',
               'Never_married',
               'Male_population',
               'Percent_Male_population',
               'Female_population',
               'Percent_Female_population',
               'Under_3_years_population',
               '3_and_4_years_population',
               '5_years_population',
               '6_to_8_years_population',
               '9_to_11_years_population',
               '12_to_14_years_population',
               '15_to_17_years_population']

# %%
king_csv_df_new.columns = new_headers
king_csv_df_new.shape
# Out:
# (397, 31)

# %%
king_csv_df_new.drop(king_csv_df_new.index[len(king_csv_df_new)-1])
# Out:
#            Labor_Force_Participation_Rate Employment_Population_Ratio  \
# Tract name
# 2.00                                 67.5                        63.2
# 3.00                                 74.3                        72.5
# 4.01                                 59.7                        56.5
# 4.02                                 64.6                        62.2
# 5.00                                 62.0                        60.6
# ...                                   ...                         ...
# 326.02                               75.6                        72.7
# 327.02                               76.3                        74.4
# 327.03                               79.4                        75.7
# 327.04                               70.0                        65.8
# 328.00                               68.5                        66.5
#
#            Unemployment_rate  Work_Travel_Less_5_mins  \
# Tract name
# 2.00                     6.0                        0
# 3.00                     2.5                       11
# 4.01                     4.9                       34
# 4.02                     3.8                        0
# 5.00                     2.3                        9
# ...                      ...                      ...
# 326.02                   3.5                      256
# 327.02                   2.4                       53
# 327.03                   4.6                       98
# 327.04                   6.0                       52
# 328.00                   2.9                       16
#
#             Work_Travel_5_to_9_mins  Work_Travel_10_to_14_mins  \
# Tract name
# 2.00                            217                        517
# 3.00                             93                         95
# 4.01                            114                        245
# 4.02                            157                        224
# 5.00                             47                         50
# ...                             ...                        ...
# 326.02                          199                        274
# 327.02                          155                        202
# 327.03                          207                         65
# 327.04                          514                        288
# 328.00                           78                        104
#
#             Work_Travel_15_to_19_mins  Work_Travel_20_to_24_mins  \
# Tract name
# 2.00                              407                        536
# 3.00                              158                        338
# 4.01                              280                        759
# 4.02                              326                        380
# 5.00                              117                        240
# ...                               ...                        ...
# 326.02                            524                        529
# 327.02                            342                        351
# 327.03                            115                        135
# 327.04                            339                        215
# 328.00                             52                         67
#
#             Work_Travel_25_to_29_mins  Work_Travel_30_to_34_mins  ...  \
# Tract name                                                        ...
# 2.00                              386                        633  ...
# 3.00                               83                        300  ...
# 4.01                              365                        518  ...
# 4.02                              173                        575  ...
# 5.00                              132                        307  ...
# ...                               ...                        ...  ...
# 326.02                            302                        992  ...
# 327.02                            178                        483  ...
# 327.03                             86                        201  ...
# 327.04                            130                        347  ...
# 328.00                             64                        242  ...
#
#             Percent_Male_population  Female_population  \
# Tract name
# 2.00                            (X)               4057
# 3.00                            (X)               1379
# 4.01                            (X)               3663
# 4.02                            (X)               2592
# 5.00                            (X)               1530
# ...                             ...                ...
# 326.02                          (X)               6829
# 327.02                          (X)               3113
# 327.03                          (X)               1106
# 327.04                          (X)               3429
# 328.00                          (X)               1108
#
#             Percent_Female_population  Under_3_years_population  \
# Tract name
# 2.00                              (X)                       202
# 3.00                              (X)                        97
# 4.01                              (X)                       288
# 4.02                              (X)                        80
# 5.00                              (X)                       128
# ...                               ...                       ...
# 326.02                            (X)                       981
# 327.02                            (X)                       200
# 327.03                            (X)                        77
# 327.04                            (X)                       229
# 328.00                            (X)                        24
#
#             3_and_4_years_population 5_years_population  \
# Tract name
# 2.00                             188                 33
# 3.00                              21                 43
# 4.01                             150                 34
# 4.02                              48                 79
# 5.00                              57                 55
# ...                              ...                ...
# 326.02                           591                333
# 327.02                           148                 93
# 327.03                            84                 21
# 327.04                           244                178
# 328.00                            25                 30
#
#            6_to_8_years_population 9_to_11_years_population  \
# Tract name
# 2.00                           277                      204
# 3.00                           112                       55
# 4.01                            38                       47
# 4.02                           118                      165
# 5.00                            57                      106
# ...                            ...                      ...
# 326.02                         733                      999
# 327.02                         275                      402
# 327.03                         106                       92
# 327.04                         209                      343
# 328.00                          40                       93
#
#            12_to_14_years_population 15_to_17_years_population
# Tract name
# 2.00                              97                       199
# 3.00                             125                        54
# 4.01                               0                       277
# 4.02                              80                        49
# 5.00                              76                       125
# ...                              ...                       ...
# 326.02                           530                       475
# 327.02                           284                       220
# 327.03                            84                       105
# 327.04                           271                       256
# 328.00                           126                        78
#
# [396 rows x 31 columns]

# %%
def hist_plots(df, i, j):
    column_list = [df.columns[x:x+j] for x in range(0, len(df.columns), j)]
    fig, axes = plt.subplots(i, j, figsize=(15, 30),
                             sharey=True,
                             tight_layout=False)
    for n in range(i):
        for m in range(j):
            column = column_list[n][m]
            df1 = df[column].dropna()
            axes[n, m].hist(df1, color='orange')
            axes[n, m].set_title(column)
            axes[n, m].set_xlabel('')
            axes[n, m].set_ylabel('')

hist_plots(king_csv_df_new, 8, 4)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-b2748459b225> in <module>
#      13             axes[n, m].set_ylabel('')
#      14
# ---> 15 hist_plots(king_csv_df_new, 8, 4)
#
# <ipython-input-38-b2748459b225> in hist_plots(df, i, j)
#       6     for n in range(i):
#       7         for m in range(j):
# ----> 8             column = column_list[n][m]
#       9             df1 = df[column].dropna()
#      10             axes[n, m].hist(df1, color='orange')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    4278         if is_scalar(key):
#    4279             key = com.cast_scalar_indexer(key)
# -> 4280             return getitem(key)
#    4281
#    4282         if isinstance(key, slice):
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %%
king_csv_df_new.drop(columns=['Percent_Male_population', 'Percent_Female_population'], inplace=True)
king_csv_df_new.head()
# Out:
#            Labor_Force_Participation_Rate Employment_Population_Ratio  \
# Tract name
# 2.00                                 67.5                        63.2
# 3.00                                 74.3                        72.5
# 4.01                                 59.7                        56.5
# 4.02                                 64.6                        62.2
# 5.00                                 62.0                        60.6
#
#            Unemployment_rate  Work_Travel_Less_5_mins  \
# Tract name
# 2.00                     6.0                        0
# 3.00                     2.5                       11
# 4.01                     4.9                       34
# 4.02                     3.8                        0
# 5.00                     2.3                        9
#
#             Work_Travel_5_to_9_mins  Work_Travel_10_to_14_mins  \
# Tract name
# 2.00                            217                        517
# 3.00                             93                         95
# 4.01                            114                        245
# 4.02                            157                        224
# 5.00                             47                         50
#
#             Work_Travel_15_to_19_mins  Work_Travel_20_to_24_mins  \
# Tract name
# 2.00                              407                        536
# 3.00                              158                        338
# 4.01                              280                        759
# 4.02                              326                        380
# 5.00                              117                        240
#
#             Work_Travel_25_to_29_mins  Work_Travel_30_to_34_mins  ...  \
# Tract name                                                        ...
# 2.00                              386                        633  ...
# 3.00                               83                        300  ...
# 4.01                              365                        518  ...
# 4.02                              173                        575  ...
# 5.00                              132                        307  ...
#
#             Never_married  Male_population  Female_population  \
# Tract name
# 2.00                 38.0             3916               4057
# 3.00                 34.5             1443               1379
# 4.01                 43.5             3058               3663
# 4.02                 36.6             2708               2592
# 5.00                 18.4             1522               1530
#
#             Under_3_years_population  3_and_4_years_population  \
# Tract name
# 2.00                             202                       188
# 3.00                              97                        21
# 4.01                             288                       150
# 4.02                              80                        48
# 5.00                             128                        57
#
#            5_years_population 6_to_8_years_population  \
# Tract name
# 2.00                       33                     277
# 3.00                       43                     112
# 4.01                       34                      38
# 4.02                       79                     118
# 5.00                       55                      57
#
#            9_to_11_years_population 12_to_14_years_population  \
# Tract name
# 2.00                            204                        97
# 3.00                             55                       125
# 4.01                             47                         0
# 4.02                            165                        80
# 5.00                            106                        76
#
#            15_to_17_years_population
# Tract name
# 2.00                             199
# 3.00                              54
# 4.01                             277
# 4.02                              49
# 5.00                             125
#
# [5 rows x 29 columns]

# %%
king_csv_df_new.to_csv('acs_wa_king_final.csv')
